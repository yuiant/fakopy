# %%
from KB.model.base import KnowledgeBase

# %%
kb = KnowledgeBase('./data/core/')

# %%
# 所有类
kb._maintainer.types
# Out:
# {'Season': <class 'KB.model.knowledge.Type'>:Season,季,
#  'TelevisionChannel': <class 'KB.model.knowledge.Type'>:TelevisionChannel,电视频道,
#  'CampingPitch': <class 'KB.model.knowledge.Type'>:CampingPitch,露营地的一个露营点,
#  'ExhibitionEvent': <class 'KB.model.knowledge.Type'>:ExhibitionEvent,活动：和展览有关的,
#  'MusicVenue': <class 'KB.model.knowledge.Type'>:MusicVenue,音乐演出场地,
#  'TaxiService': <class 'KB.model.knowledge.Type'>:TaxiService,出租车服务,
#  'PayAction': <class 'KB.model.knowledge.Type'>:PayAction,动作：付款,
#  'Hostel': <class 'KB.model.knowledge.Type'>:Hostel,招待所,
#  'Recipe': <class 'KB.model.knowledge.Type'>:Recipe,菜谱,
#  'ApplyAction': <class 'KB.model.knowledge.Type'>:ApplyAction,动作：申请,
#  'Synagogue': <class 'KB.model.knowledge.Type'>:Synagogue,犹太教会堂,
#  'RadioStation': <class 'KB.model.knowledge.Type'>:RadioStation,无线广播电台,
#  'SiteNavigationElement': <class 'KB.model.knowledge.Type'>:SiteNavigationElement,站点导航网页元素,
# ...

# %%
# 所有属性
kb._maintainer.properties
# Out:
# {'catalogNumber': <class 'KB.model.knowledge.Property'>:catalogNumber,目录中的编号,
#  'workExample': <class 'KB.model.knowledge.Property'>:workExample,作品的范例,
#  'commentText': <class 'KB.model.knowledge.Property'>:commentText,评论文字,
#  'height': <class 'KB.model.knowledge.Property'>:height,高度,
#  'mapType': <class 'KB.model.knowledge.Property'>:mapType,地图类型,
#  'arrivalAirport': <class 'KB.model.knowledge.Property'>:arrivalAirport,到达机场,
#  'reviewCount': <class 'KB.model.knowledge.Property'>:reviewCount,评论总数,
#  'bitrate': <class 'KB.model.knowledge.Property'>:bitrate,比特率,
#  'orderItemStatus': <class 'KB.model.knowledge.Property'>:orderItemStatus,订单条目的状态,
#  'availableFrom': <class 'KB.model.knowledge.Property'>:availableFrom,提货开始时间,
#  'accessibilityControl': <class 'KB.model.knowledge.Property'>:accessibilityControl,无障碍环境服务控制方法,
#  'image': <class 'KB.model.knowledge.Property'>:image,图片,
#  'illustrator': <class 'KB.model.knowledge.Property'>:illustrator,插图绘制者,
# ...

# %%
# 所有实体
kb._maintainer.entities
# Out:
# {'consensus': <class 'KB.model.knowledge.Entity'>:consensus,None,
#  'Daniel Coffman': <class 'KB.model.knowledge.Entity'>:Daniel Coffman,None,
#  'shipchain': <class 'KB.model.knowledge.Entity'>:shipchain,None,
#  'pipcoin': <class 'KB.model.knowledge.Entity'>:pipcoin,None,
#  'wavesgo': <class 'KB.model.knowledge.Entity'>:wavesgo,None,
#  'echolink': <class 'KB.model.knowledge.Entity'>:echolink,None,
#  'adx-net': <class 'KB.model.knowledge.Entity'>:adx-net,None,
#  'sisa': <class 'KB.model.knowledge.Entity'>:sisa,None,
#  'sbgcoin': <class 'KB.model.knowledge.Entity'>:sbgcoin,什币股,
#  'adshares': <class 'KB.model.knowledge.Entity'>:adshares,None,
#  'tracto': <class 'KB.model.knowledge.Entity'>:tracto,None,
#  'wowcoin': <class 'KB.model.knowledge.Entity'>:wowcoin,华币,
#  'uniburst': <class 'KB.model.knowledge.Entity'>:uniburst,None,
#  'ark': <class 'KB.model.knowledge.Entity'>:ark,None,
#  'safecoin': <class 'KB.model.knowledge.Entity'>:safecoin,None,
# ...

# %%
# 所有关系
kb._maintainer.relations
# Out:
# {}

# %%
# 搜索
kb.search('比特币')
# Out:
# [<class 'KB.model.knowledge.Thing'>:None,比特币,
#  <class 'KB.model.knowledge.Thing'>:None,位元幣,
#  <class 'KB.model.knowledge.Thing'>:None,比特币,
#  <class 'KB.model.knowledge.Thing'>:None,比特幣,
#  <class 'KB.model.knowledge.Thing'>:None,Bitcoin,
#  <class 'KB.model.knowledge.Thing'>:None,XBT,
#  <class 'KB.model.knowledge.Thing'>:None,₿,
#  <class 'KB.model.knowledge.Thing'>:None,位元幣,
#  <class 'KB.model.knowledge.Thing'>:None,None]

# %%
b =kb.query('比特币')[0]

# %%
b
# Out:
# <class 'KB.model.knowledge.Entity'>:bitcoin,比特币

# %%
b.properties
# Out:
# [{'CreativeWork': {'about': None,
#    'accessMode': None,
#    'accessModeSufficient': None,
#    'accessibilityAPI': None,
#    'accessibilityControl': None,
#    'accessibilityFeature': None,
#    'accessibilityHazard': None,
#    'accessibilitySummary': None,
#    'accountablePerson': None,
#    'aggregateRating': None,
#    'alternativeHeadline': None,
#    'associatedMedia': None,
#    'audience': None,
#    'audio': None,
#    'author': None,
#    'award': None,
#    'character': None,
#    'citation': None,
#    'comment': None,
#    'commentCount': None,
#    'contentLocation': None,
#    'contentRating': None,
#    'contributor': None,
#    'copyrightHolder': None,
#    'copyrightYear': None,
#    'creator': None,
#    'dateCreated': None,
#    'dateModified': None,
#    'datePublished': None,
#    'discussionUrl': None,
#    'editor': None,
#    'educationalAlignment': None,
#    'educationalUse': None,
#    'encoding': None,
#    'exampleOfWork': None,
# ...
